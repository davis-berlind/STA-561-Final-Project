# %%
from fred import Fred
import numpy as np
import pandas as pd

# FRED API key
key = 'YOUR KEY GOES HERE'

## Getting Data from FRED ##
fr = Fred(api_key = key, response_type = 'df')

# setting data parameters
params = {'observation_start': '1995-01-01',
          'observation_end': '2010-01-01'}

# Load list of data series
fseries = pd.read_csv("FRED_data_series.csv")

#fr.series.observations('', params = params)
# Out:
#     File                                      \
# 0                               CAPUTLN2121S
# 1                               CAPUTLG3342S
# 2                               CAPUTLG3341S
# 3                              CAPUTLHITEK2S
# 4                              CAPUTLB5610CS
# 5                                CAPUTLGMFDS
# 6                             CAPUTLG3364T9S
# 7                              CAPUTLG33611S
# 8                                CAPUTLG334S
# 9                                CAPUTLG335S
# 10                               CAPUTLG332S
# 11                               CAPUTLG337S
# 12                            CAPUTLG3311A2S
# 13                               CAPUTLG333S
# 14                               CAPUTLG339S
# 15                            CAPUTLG3361T3S
# 16                               CAPUTLG327S
# 17                               CAPUTLG331S
# 18                               CAPUTLG336S
# 19                               CAPUTLG321S
# 20                            CAPUTLG2211A2S
# 21                              CAPUTLG2211S
# 22                             CAPUTLB5640CS
# 23                                    MCUMFN
# 24                                    CUMFNS
# 25                             CAPUTLX4HTK2S
# 26                             CAPUTLX4HTMVS
# 27                              CAPUTLG2122S
# 28                                CAPUTLG21S
# 29                               CAPUTLG212S
# ..                                       ...
# 459                                 CPIRECSL
# 460                             CUSR0000SEHA
# 461                           CUSR0000SAS2RS
# 462                              CUSR0000SAS
# 463                           CUSR0000SEMC04
# 464                            CUSR0000SASLE
# 465                            CUSR0000SASL5
# 466                          CUSR0000SASL2RS
# 467                             CUSR0000SAH1
# 468                             CUSR0000SEFR
# 469                             CUSR0000SEGA
# 470                           CUSR0000SERE01
# 471                                 CPITRNSL
# 472                             CUSR0000SAS4
# 473                             CUSR0000SEEB
# 474                           CUSR0000SETA02
# 475                             CUSR0000SERA
# 476                            CUSR0000SERAC
# 477                             CUSR0000SEHG
# 478                             CUSR0000SAA2
# 479                                   PPIAWS
# 480                                   PPIDCS
# 481                                   PPIDES
# 482                                   PPIDFS
# 483                                   PPIDGS
# 484                                   PPIDSS
# 485                                   PPIFES
# 486                                   PPIFIS
# 487                                   PPITSS
# 488                                   PPITWS
#
#                                                  Title                  Units  \
# 0                    Capacity Utilization: Coal mining          % of Capacity
# 1       Capacity Utilization: Communications equipment          % of Capacity
# 2    Capacity Utilization: Computer and peripheral ...          % of Capacity
# 3    Capacity Utilization: Computers, communication...          % of Capacity
# 4               Capacity Utilization: Crude processing          % of Capacity
# 5          Capacity Utilization: Durable manufacturing          % of Capacity
# 6    Capacity Utilization: Durable Manufacturing: A...          % of Capacity
# 7    Capacity Utilization: Durable Manufacturing: A...          % of Capacity
# 8    Capacity Utilization: Durable Manufacturing: C...          % of Capacity
# 9    Capacity Utilization: Durable Manufacturing: E...          % of Capacity
# 10   Capacity Utilization: Durable Manufacturing: F...          % of Capacity
# 11   Capacity Utilization: Durable Manufacturing: F...          % of Capacity
# 12   Capacity Utilization: Durable Manufacturing: I...          % of Capacity
# 13   Capacity Utilization: Durable Manufacturing: M...          % of Capacity
# 14   Capacity Utilization: Durable Manufacturing: M...          % of Capacity
# 15   Capacity Utilization: Durable Manufacturing: M...          % of Capacity
# 16   Capacity Utilization: Durable Manufacturing: N...          % of Capacity
# 17   Capacity Utilization: Durable Manufacturing: P...          % of Capacity
# 18   Capacity Utilization: Durable Manufacturing: T...          % of Capacity
# 19   Capacity Utilization: Durable Manufacturing: W...          % of Capacity
# 20    Capacity Utilization: Electric and gas utilities          % of Capacity
# 21   Capacity Utilization: Electric power generatio...          % of Capacity
# 22           Capacity Utilization: Finished processing          % of Capacity
# 23         Capacity Utilization: Manufacturing (NAICS)          % of Capacity
# 24           Capacity Utilization: Manufacturing (SIC)          % of Capacity
# 25   Capacity Utilization: Manufacturing excluding ...          % of Capacity
# 26   Capacity Utilization: Manufacturing excluding ...          % of Capacity
# 27              Capacity Utilization: Metal ore mining          % of Capacity
# 28                        Capacity Utilization: Mining          % of Capacity
# 29   Capacity Utilization: Mining (except oil and gas)          % of Capacity
# ..                                                 ...                    ...
# 459  Consumer Price Index for All Urban Consumers: ...     Index Dec 1997=100
# 460  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 461  Consumer Price Index for All Urban Consumers: ...     Index Dec 1982=100
# 462  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 463  Consumer Price Index for All Urban Consumers: ...     Index Dec 1986=100
# 464  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 465  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 466  Consumer Price Index for All Urban Consumers: ...     Index Dec 1982=100
# 467  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 468  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 469  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 470  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 471  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 472  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 473  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 474  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 475  Consumer Price Index for All Urban Consumers: ...     Index Dec 1997=100
# 476  Consumer Price Index for All Urban Consumers: ...     Index Dec 2009=100
# 477  Consumer Price Index for All Urban Consumers: ...     Index Dec 1997=100
# 478  Consumer Price Index for All Urban Consumers: ...      Index 1982-84=100
# 479  Producer Price Index by Commodity for Final De...    Index Nov 2009= 100
# 480  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 481  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 482  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 483  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 484  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 485  Producer Price Index by Commodity for Final De...     Index Apr 2010=100
# 486  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 487  Producer Price Index by Commodity for Final De...   Index Nov 2009 = 100
# 488  Producer Price Index by Commodity for Final De...    Index Nov 2009= 100
#
#      Frequency  Seasonal Adjustment  Last Updated Category
# 0            M                   SA    2018-12-14      out
# 1            M                   SA    2018-12-14      out
# 2            M                   SA    2018-12-14      out
# 3            M                   SA    2018-12-14      out
# 4            M                   SA    2018-12-14      out
# 5            M                   SA    2018-12-14      out
# 6            M                   SA    2018-12-14      out
# 7            M                   SA    2018-12-14      out
# 8            M                   SA    2018-12-14      out
# 9            M                   SA    2018-12-14      out
# 10           M                   SA    2018-12-14      out
# 11           M                   SA    2018-12-14      out
# 12           M                   SA    2018-12-14      out
# 13           M                   SA    2018-12-14      out
# 14           M                   SA    2018-12-14      out
# 15           M                   SA    2018-12-14      out
# 16           M                   SA    2018-12-14      out
# 17           M                   SA    2018-12-14      out
# 18           M                   SA    2018-12-14      out
# 19           M                   SA    2018-12-14      out
# 20           M                   SA    2018-12-14      out
# 21           M                   SA    2018-12-14      out
# 22           M                   SA    2018-12-14      out
# 23           M                   SA    2018-12-14      out
# 24           M                   SA    2018-12-14      out
# 25           M                   SA    2018-12-14      out
# 26           M                   SA    2018-12-14      out
# 27           M                   SA    2018-12-14      out
# 28           M                   SA    2018-12-14      out
# 29           M                   SA    2018-12-14      out
# ..         ...                  ...           ...      ...
# 459          M                   SA    2019-01-11      Pri
# 460          M                   SA    2019-01-11      Pri
# 461          M                   SA    2019-01-11      Pri
# 462          M                   SA    2019-01-11      Pri
# 463          M                   SA    2019-01-11      Pri
# 464          M                   SA    2019-01-11      Pri
# 465          M                   SA    2019-01-11      Pri
# 466          M                   SA    2019-01-11      Pri
# 467          M                   SA    2019-01-11      Pri
# 468          M                   SA    2019-01-11      Pri
# 469          M                   SA    2019-01-11      Pri
# 470          M                   SA    2019-01-11      Pri
# 471          M                   SA    2019-01-11      Pri
# 472          M                   SA    2019-01-11      Pri
# 473          M                   SA    2019-01-11      Pri
# 474          M                   SA    2019-01-11      Pri
# 475          M                   SA    2019-01-11      Pri
# 476          M                   SA    2019-01-11      Pri
# 477          M                   SA    2019-01-11      Pri
# 478          M                   SA    2019-01-11      Pri
# 479          M                   SA    2018-12-11      NaN
# 480          M                   SA    2018-12-11      NaN
# 481          M                   SA    2018-12-11      NaN
# 482          M                   SA    2018-12-11      NaN
# 483          M                   SA    2018-12-11      NaN
# 484          M                   SA    2018-12-11      NaN
# 485          M                   SA    2018-12-11      NaN
# 486          M                   SA    2018-12-11      NaN
# 487          M                   SA    2018-12-11      NaN
# 488          M                   SA    2018-12-11      NaN
#
# [489 rows x 7 columns]
